# %% [markdown]
# <a href="https://colab.research.google.com/github/alizaishoaib567-art/Currency-Converter-API/blob/main/Week_9_Git_GitHub_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("===== SIMPLE CALCULATOR =====")

number1 = float(input("Enter first number: "))
number2 = float(input("Enter second number: "))

print("Choose an operation: +, -, *, /")
operation = input("Enter operation: ")

if operation == "+":
    print("Answer:", number1 + number2)

elif operation == "-":
    print("Answer:", number1 - number2)

elif operation == "*":
    print("Answer:", number1 * number2)

elif operation == "/":
    if number2 == 0:
        print("Division by zero is not possible.")
    else:
        print("Answer:", number1 / number2)

else:
    print("Invalid operation.")
# Out:
# ===== SIMPLE CALCULATOR =====
# Enter first number: 12
# Enter second number: 4
# Choose an operation: +, -, *, /
# Enter operation: *
# Answer: 48.0
